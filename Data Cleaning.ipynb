# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("/content/drive/MyDrive/DATATHON - THE DATA SQUAD/Academic Survey (Responses).xlsx", sheet_name=0)
data
# Out:
#                  Timestamp        1. Age 2. Gender 3. Grade/Class  \
# 0  2024-10-02 21:41:42.214  18 and above      Male       Graduate
# 1  2024-10-02 21:41:45.763  18 and above      Male       Graduate
# 2  2024-10-02 21:48:14.448  18 and above    Female       Graduate
# 3  2024-10-02 22:41:19.957  18 and above      Male       Graduate
# 4  2024-10-03 01:18:20.571  18 and above    Female       Graduate
# ..                     ...           ...       ...            ...
# 67 2024-10-04 14:21:29.451       16 - 17      Male       Graduate
# 68 2024-10-04 14:32:34.849       16 - 17    Female       Graduate
# 69 2024-10-04 14:45:32.742  18 and above      Male       Graduate
# 70 2024-10-04 15:41:03.797       16 - 17    Female       Graduate
# 71 2024-10-04 17:11:19.387  18 and above      Male       Graduate
#
#    4. Class Type 5. Location 6. Type of School 7. Nature of School  \
# 0        Science    Suburban           Private                 Day
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 40 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Timestamp                                                                                                                  72 non-null     datetime64[ns]
#  1   1. Age                                                                                                                     72 non-null     object
#  2   2. Gender                                                                                                                  72 non-null     object
# ...

# %%
#renaming columns
data = data.rename(columns= {"1. Age": "Age", "3. Grade/Class":"Class", "2. Gender":"Gender",
                             "4. Class Type":"Class Type", "5. Location":"Location", "6. Type of School":"Type of School",
                             "7. Nature of School":"Nature of School", "8. How would you rate the quality of teaching in your school?":"Quality of Teaching",
                             "9. How often do you receive feedback on your academic performance?":"Academic Performance Feedback",
                             "10. Do you feel that your teachers are well-prepared and knowledgeable?":"Quality of Teachers",
                             "11. Availability of learning resources (books, internet, laboratories, extra lessons or tutorials)":"Availability of Learning Resources",
                             "12. How comfortable is your classroom environment for learning? ": "Learning Environment", "13. What is your family’s monthly income range?": "Family's Monthly Income",
                             "14. Do you have access to a quiet place to study at home?":"Home Study", "15. Do you receive financial support for your education? (e.g., scholarships, loans)":"Financial Support",
                             "17. How many hours do you study per day outside of school hours?":"Outside School Study Hours",
                             "18. Do you participate in extracurricular activities?":"Extracurricular activities", "19.  How would you rate your motivation to perform well academically?":"Academic Motivation",
                             "20. Do you experience stress related to your studies?": "Academic-related Stress", "21. What are your primary sources of stress? (Select all that apply)":"Sources of Stress",
                             "22. How many credits and above did you have in your WASSCE? (For Graduates)":"Number of credits and above in WASSCE", "23. What was your JAMB score? (For Graduates)": "Jamb Score",
                             "24.  How would you rate your overall intelligence compared to your classmates? " :"Intelligence Rating", "25.  What type of student do you consider yourself to be academically? ":"Type of Student",
                             "26.  How confident are you in your ability to perform well in upcoming exams (e.g., JAMB, WASSCE)? ":"Confidence in Ability",
                             "28.  How often do you solve problems or tasks that challenge your thinking ability (e.g., puzzles, academic challenges)? ": "Ability to solve problems",
                             "29.  What is your preferred learning style? (Select all that apply) ": "Learning Style", "32.  Have you participated in any Computer-Based Test (CBT) exams as preparation for your JAMB? ":"Preparatory CBT",
                             "33.  If yes, how many CBT practice exams have you taken in preparation for your JAMB?":"Number of preparatory CBT taken", "35.  If yes, how often do you attend these extra lessons? ": "Number of extra lessons attended",
                             "37.  How do you prefer to prepare for your final exams? ":"Method of Exam Preparation", "38.  How many hours do you spend studying daily to prepare for your final exams? ":"Daily Study Hours"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 40 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Timestamp                                                                                                72 non-null     datetime64[ns]
#  1   Age                                                                                                      72 non-null     object
#  2   Gender                                                                                                   72 non-null     object
#  3   Class                                                                                                    72 non-null     object
# ...

# %%
data = data.drop(["16.  How does your family’s financial situation affect your studies?", "27.  Do you believe that intelligence is something that can improve with effort? ",
                  "30.  How often do you feel proud of your academic achievements? ", "31.   Do you think your current academic performance reflects your true potential? ", "34.  Do you attend extra lessons specifically for your final exams (JAMB, WASSCE)? ",
                  "36.  Do you think attending extra lessons helps improve your exam performance? ", "39.  Do you feel that the current study methods you use are effective in preparing you for your exams? "], axis ="columns")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Timestamp                              72 non-null     datetime64[ns]
#  1   Age                                    72 non-null     object
#  2   Gender                                 72 non-null     object
#  3   Class                                  72 non-null     object
#  4   Class Type                             72 non-null     object
#  5   Location                               72 non-null     object
#  6   Type of School                         72 non-null     object
#  7   Nature of School                       72 non-null     object
#  8   Quality of Teaching                    72 non-null     object
#  9   Academic Performance Feedback          72 non-null     object
# ...

# %%
data["Sources of Stress"] = data["Sources of Stress"].str.strip(" ")
data["Sources of Stress"].value_counts()
# Out:
# Sources of Stress
# Social relationships                                                              12
# Academic pressure                                                                 11
# Family expectations                                                                7
# Academic pressure, Family expectations                                             7
# Academic pressure, Financial issues                                                5
# Financial issues                                                                   5
# Academic pressure, Family expectations, Financial issues                           5
# Academic pressure, Family expectations, Financial issues, Social relationships     5
# Academic pressure, Family expectations, Social relationships                       4
# Academic pressure, Financial issues, Social relationships                          3
# Academic pressure, Social relationships                                            2
# ...

# %%
for i in range(0,len(data)):
  if data["Class"][i]!="Graduate":
    data["Number of credits and above in WASSCE"][i] = 0
    data["Jamb Score"][i] = 0
# Out:
# <ipython-input-9-b76fb86e1cdd>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["Number of credits and above in WASSCE"][i] = 0
# <ipython-input-9-b76fb86e1cdd>:3: SettingWithCopyWarning:
# ...

# %%
data["Number of credits and above in WASSCE"].value_counts()
# Out:
# Number of credits and above in WASSCE
# 9.0    21
# 0.0    19
# 5.0    10
# 8.0     4
# 7.0     4
# 6.0     3
# 3.0     2
# 1.0     1
# 4.0     1
# 2.0     1
# Name: count, dtype: int64

# %%
data["Jamb Score"].value_counts()
# Out:
# Jamb Score
# 0.0      20
# 250.0     2
# 291.0     2
# 221.0     2
# 262.0     2
# 236.0     2
# 304.0     1
# 218.0     1
# 244.0     1
# 228.0     1
# 213.0     1
# 287.0     1
# 315.0     1
# 212.0     1
# 239.0     1
# 251.0     1
# 169.0     1
# 306.0     1
# 265.0     1
# 355.0     1
# 298.0     1
# 334.0     1
# 235.0     1
# 233.0     1
# 210.0     1
# 202.0     1
# 297.0     1
# 260.0     1
# 234.0     1
# 275.0     1
# 278.0     1
# 220.0     1
# 243.0     1
# 222.0     1
# 227.0     1
# 203.0     1
# 285.0     1
# 267.0     1
# 341.0     1
# 288.0     1
# 268.0     1
# Name: count, dtype: int64

# %%
data[data["Class"]!="Graduate"]
# Out:
#                  Timestamp           Age  Gender Class  Class Type  Location  \
# 8  2024-10-03 10:58:59.577       14 - 15  Female   SS2        Arts     Urban
# 10 2024-10-03 11:40:15.510       16 - 17    Male   SS2  Commercial     Urban
# 15 2024-10-03 11:53:58.872       16 - 17  Female   SS1  Commercial     Urban
# 27 2024-10-03 13:39:38.381       14 - 15    Male   SS1        Arts     Urban
# 38 2024-10-03 14:35:00.906  18 and above  Female   SS3        Arts  Suburban
# 42 2024-10-03 15:06:47.695       14 - 15  Female   SS2        Arts     Urban
# 47 2024-10-03 17:23:07.936       14 - 15  Female   SS3  Commercial     Rural
# 50 2024-10-03 18:19:47.433       14 - 15  Female   SS3     Science     Urban
# 51 2024-10-03 18:22:37.344       14 - 15  Female   SS3     Science     Urban
# 52 2024-10-03 18:27:45.990       14 - 15  Female   SS3     Science     Urban
# 55 2024-10-03 19:06:31.761       16 - 17  Female   SS3     Science  Suburban
# ...

# %%
data["Learning Environment"] = data["Learning Environment"].astype("object")

# %%
data["Number of credits and above in WASSCE"].fillna(0, inplace=True)
# Out:
# <ipython-input-14-b9b7bec9b1ae>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Number of credits and above in WASSCE"].fillna(0, inplace=True)

# %%
data["Jamb Score"].fillna(0, inplace=True)
# Out:
# <ipython-input-15-7141a508d8a1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Jamb Score"].fillna(0, inplace=True)

# %%
data["Sources of Stress"].fillna("None", inplace=True)
# Out:
# <ipython-input-16-4d31fa1fe902>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Sources of Stress"].fillna("None", inplace=True)

# %%
data["Number of preparatory CBT taken"].fillna("None", inplace=True)
# Out:
# <ipython-input-17-e121fbeaae55>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Number of preparatory CBT taken"].fillna("None", inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 33 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Timestamp                              72 non-null     datetime64[ns]
#  1   Age                                    72 non-null     object
#  2   Gender                                 72 non-null     object
#  3   Class                                  72 non-null     object
#  4   Class Type                             72 non-null     object
#  5   Location                               72 non-null     object
#  6   Type of School                         72 non-null     object
#  7   Nature of School                       72 non-null     object
#  8   Quality of Teaching                    72 non-null     object
#  9   Academic Performance Feedback          72 non-null     object
# ...

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      38
# Female    34
# Name: count, dtype: int64

# %%
data.to_csv("/content/drive/MyDrive/DATATHON - THE DATA SQUAD/Cleaned Academic Survey.csv", index=0)
